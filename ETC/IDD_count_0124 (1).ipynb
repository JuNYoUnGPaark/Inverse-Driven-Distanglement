# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from dataclasses import dataclass
from typing import Dict, List, Tuple

import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.metrics import roc_auc_score


# --------------------------------
# 0) CONFIG
# --------------------------------
CONFIG = {
    "data_dir": "/content/drive/MyDrive/Colab Notebooks/HAR_data/MHEALTHDATASET",
    "fs": 50,
    "subjects": list(range(1, 11)),
    "activities": [6, 7, 8, 12],

    "window_size": 50,
    "stride": 25,

    "trial_norm": True,
    "trial_norm_eps": 1e-6,

    "epochs": 50,
    "batch_size": 128,
    "lr": 1e-3,
    "seed": 42,
    "device": "cuda" if torch.cuda.is_available() else "cpu",

    "beta_sigmoid": 1.0,
    "robust_eps": 1e-6,
    "grav_lp_win": 25,

    "tb_frac": 0.20,

    "lambda_recon": 1.0,
    "lambda_bce": 1.0,
    "lambda_contrast": 0.3,
    "lambda_sparsity": 0.2,
    "lambda_tv": 0.2,

    "count_smooth_win": 9,
    "min_bpm": 10,
    "max_bpm": 120,
}


# --------------------------------
# 1) USER GT COUNT TABLE (EVAL ONLY)
# --------------------------------
COUNT_TABLE: Dict[int, Dict[str, int]] = {
    6: {
        "subject1": 21, "subject2": 19, "subject3": 21, "subject4": 20, "subject5": 20,
        "subject6": 20, "subject7": 20, "subject8": 21, "subject9": 21, "subject10": 20,
    },
    7: {
        "subject1": 20, "subject2": 20, "subject3": 20, "subject4": 20, "subject5": 20,
        "subject6": 20, "subject7": 20, "subject8": 19, "subject9": 19, "subject10": 20,
    },
    8: {
        "subject1": 20, "subject2": 21, "subject3": 21, "subject4": 19, "subject5": 20,
        "subject6": 20, "subject7": 21, "subject8": 21, "subject9": 21, "subject10": 21,
    },
    12: {
        "subject1": 40, "subject2": 44, "subject3": 42, "subject4": 42, "subject5": 40,
        "subject6": 42, "subject7": 38, "subject8": 40, "subject9": 40, "subject10": 40,
    },
}


# --------------------------------
# 2) UTIL
# --------------------------------
def set_seed(seed: int = 42):
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)


def safe_sigmoid_np(x: np.ndarray):
    x = np.clip(x, -30.0, 30.0)
    return 1.0 / (1.0 + np.exp(-x))


def robust_z(x: np.ndarray, eps: float = 1e-6) -> np.ndarray:
    med = np.median(x)
    mad = np.median(np.abs(x - med))
    denom = 1.4826 * mad + eps
    return (x - med) / denom


def moving_average_1d(x: np.ndarray, win: int) -> np.ndarray:
    if win <= 1:
        return x
    win = int(win)
    kernel = np.ones(win, dtype=np.float32) / float(win)
    pad = win // 2
    xp = np.pad(x, (pad, pad), mode="reflect")
    return np.convolve(xp, kernel, mode="valid")


def moving_average_vec(X: np.ndarray, win: int) -> np.ndarray:
    if win <= 1:
        return X
    out = np.zeros_like(X)
    for c in range(X.shape[1]):
        out[:, c] = moving_average_1d(X[:, c], win)
    return out


def l2_normalize(v: np.ndarray, eps: float = 1e-8) -> np.ndarray:
    n = np.linalg.norm(v, axis=-1, keepdims=True)
    return v / (n + eps)


def trialwise_normalize(X: np.ndarray, eps: float = 1e-6) -> Tuple[np.ndarray, np.ndarray, np.ndarray]:
    mu = X.mean(axis=0, keepdims=True)
    std = X.std(axis=0, keepdims=True)
    Xn = (X - mu) / (std + eps)
    return Xn.astype(np.float32), mu.astype(np.float32), std.astype(np.float32)


def chest_acc_mag(X18_raw: np.ndarray) -> np.ndarray:
    v = X18_raw[:, 0:3].astype(np.float32)
    return np.linalg.norm(v, axis=1).astype(np.float32)


def mask_to_spans(mask: np.ndarray) -> List[Tuple[int, int]]:
    mask = mask.astype(bool)
    if mask.sum() == 0:
        return []
    idx = np.where(mask)[0]
    spans = []
    s = idx[0]
    prev = idx[0]
    for i in idx[1:]:
        if i == prev + 1:
            prev = i
        else:
            spans.append((s, prev + 1))
            s = i
            prev = i
    spans.append((s, prev + 1))
    return spans


# --------------------------------
# 3) mHealth LOADING + TRIAL EXTRACTION
# --------------------------------
def _read_mhealth_subject_log(data_dir: str, subject_id: int) -> np.ndarray:
    fname = os.path.join(data_dir, f"mHealth_subject{subject_id}.log")
    return np.loadtxt(fname)


def _extract_activity_segments(arr: np.ndarray, activity_code: int) -> List[Tuple[int, int]]:
    labels = arr[:, -1].astype(int)
    idx = np.where(labels == activity_code)[0]
    if len(idx) == 0:
        return []
    segments = []
    s = idx[0]
    prev = idx[0]
    for i in idx[1:]:
        if i == prev + 1:
            prev = i
        else:
            segments.append((s, prev + 1))
            s = i
            prev = i
    segments.append((s, prev + 1))
    return segments


def _get_sensor_6ch(arr: np.ndarray, which: str) -> np.ndarray:
    if which == "chest":
        return arr[:, 0:6]
    if which == "ankle":
        return arr[:, 6:12]
    if which == "arm":
        return arr[:, 12:18]
    raise ValueError(which)


def build_trials_for_activity(data_dir: str, activity: int, subjects: List[int]) -> Dict[str, np.ndarray]:
    trials = {}
    for sid in subjects:
        arr = _read_mhealth_subject_log(data_dir, sid)
        segs = _extract_activity_segments(arr, activity)
        if len(segs) == 0:
            continue
        s, e = max(segs, key=lambda x: x[1] - x[0])
        chest = _get_sensor_6ch(arr[s:e], "chest")
        ankle = _get_sensor_6ch(arr[s:e], "ankle")
        arm = _get_sensor_6ch(arr[s:e], "arm")
        X = np.concatenate([chest, ankle, arm], axis=1)
        trials[f"subject{sid}"] = X.astype(np.float32)
    return trials


# --------------------------------
# 4) PSEUDO-EVENTNESS (STATE-CHANGE MAGNITUDE)
# --------------------------------
def pseudo_eventness_two_defs(
    X18_raw: np.ndarray,
    fs: int,
    beta: float,
    eps: float,
    grav_lp_win: int,
) -> np.ndarray:
    T = X18_raw.shape[0]
    if T < 5:
        return np.zeros((T,), dtype=np.float32)

    gyro = np.concatenate([X18_raw[:, 3:6], X18_raw[:, 9:12], X18_raw[:, 15:18]], axis=1)
    acc = np.concatenate([X18_raw[:, 0:3], X18_raw[:, 6:9], X18_raw[:, 12:15]], axis=1)

    dgyro = np.diff(gyro, axis=0) * fs
    jerk1 = np.linalg.norm(dgyro, axis=1).astype(np.float32)
    jerk1 = np.concatenate([[jerk1[0]], jerk1], axis=0)
    z1 = robust_z(jerk1, eps=eps).astype(np.float32)

    acc_lp = moving_average_vec(acc.astype(np.float32), grav_lp_win)
    ghat = l2_normalize(acc_lp.astype(np.float32))

    dot = np.sum(ghat[1:] * ghat[:-1], axis=1).astype(np.float32)
    dot = np.clip(dot, -1.0, 1.0)
    ang = np.arccos(dot).astype(np.float32)
    instab2 = np.concatenate([[ang[0]], ang], axis=0) * fs
    z2 = robust_z(instab2, eps=eps).astype(np.float32)

    z = (z1 + z2).astype(np.float32)
    p = safe_sigmoid_np(beta * z).astype(np.float32)
    return p


# --------------------------------
# 5) DATASET (WINDOWS)
# --------------------------------
@dataclass
class WindowItem:
    x: torch.Tensor
    p: torch.Tensor
    trial_key: str
    start: int
    W: int


class TrialWindowDataset(torch.utils.data.Dataset):
    def __init__(self, trials_raw: Dict[str, np.ndarray], cfg: Dict):
        self.cfg = cfg
        self.items: List[WindowItem] = []
        self.trials_raw = trials_raw

        W = cfg["window_size"]
        S = cfg["stride"]

        for trial_key, X18_raw in trials_raw.items():
            p = pseudo_eventness_two_defs(
                X18_raw=X18_raw,
                fs=cfg["fs"],
                beta=cfg["beta_sigmoid"],
                eps=cfg["robust_eps"],
                grav_lp_win=cfg["grav_lp_win"],
            )

            if cfg.get("trial_norm", True):
                X18, _, _ = trialwise_normalize(X18_raw, eps=cfg["trial_norm_eps"])
            else:
                X18 = X18_raw.astype(np.float32)

            T = X18.shape[0]
            if T < W:
                continue

            for st in range(0, T - W + 1, S):
                xw = X18[st:st + W]
                pw = p[st:st + W]
                xw_t = torch.from_numpy(xw).float().transpose(0, 1)
                pw_t = torch.from_numpy(pw).float()
                self.items.append(WindowItem(x=xw_t, p=pw_t, trial_key=trial_key, start=st, W=W))

    def __len__(self):
        return len(self.items)

    def __getitem__(self, idx: int):
        it = self.items[idx]
        return it.x, it.p, it.trial_key, it.start, it.W


def collate_fn(batch):
    xs, ps, keys, starts, Ws = zip(*batch)
    X = torch.stack(xs, dim=0)
    P = torch.stack(ps, dim=0)
    return X, P, list(keys), torch.tensor(starts, dtype=torch.long), torch.tensor(Ws, dtype=torch.long)


# --------------------------------
# 6) MODEL
# --------------------------------
class Encoder18(nn.Module):
    def __init__(self, in_ch: int, hid: int, out_dim: int):
        super().__init__()
        self.net = nn.Sequential(
            nn.Conv1d(in_ch, hid, kernel_size=5, padding=2),
            nn.BatchNorm1d(hid),
            nn.GELU(),
            nn.Conv1d(hid, hid, kernel_size=5, padding=2),
            nn.BatchNorm1d(hid),
            nn.GELU(),
            nn.Conv1d(hid, out_dim, kernel_size=3, padding=1),
            nn.BatchNorm1d(out_dim),
            nn.GELU(),
        )

    def forward(self, x):
        return self.net(x)


class Decoder(nn.Module):
    def __init__(self, in_dim: int, hid: int, out_ch: int):
        super().__init__()
        self.net = nn.Sequential(
            nn.Conv1d(in_dim, hid, kernel_size=5, padding=2),
            nn.BatchNorm1d(hid),
            nn.GELU(),
            nn.Conv1d(hid, hid, kernel_size=5, padding=2),
            nn.BatchNorm1d(hid),
            nn.GELU(),
            nn.Conv1d(hid, out_ch, kernel_size=3, padding=1),
        )

    def forward(self, z):
        return self.net(z)


class EventModel(nn.Module):
    def __init__(self, latent_dim: int = 64, hid: int = 128):
        super().__init__()
        self.enc = Encoder18(18, hid, latent_dim)
        self.dec = Decoder(latent_dim, hid, out_ch=18)
        self.event_head = nn.Sequential(
            nn.Conv1d(latent_dim, latent_dim, kernel_size=3, padding=1),
            nn.GELU(),
            nn.Conv1d(latent_dim, 1, kernel_size=1),
        )

    def forward(self, x18):
        z = self.enc(x18)
        xhat = self.dec(z)
        elogit = self.event_head(z).squeeze(1)
        return z, xhat, elogit


# --------------------------------
# 7) LOSSES
# --------------------------------
def contrast_top_bottom(z: torch.Tensor, pseudo_w: torch.Tensor, tb_frac: float):
    B = z.shape[0]
    if B < 8:
        return z.new_tensor(0.0)

    s = pseudo_w.mean(dim=1)
    k = max(2, int(tb_frac * B))
    idx = torch.argsort(s)
    low = idx[:k]
    high = idx[-k:]

    zw = z.mean(dim=2)
    z_low = F.normalize(zw[low], dim=1)
    z_high = F.normalize(zw[high], dim=1)

    sim_ll = torch.mm(z_low, z_low.t())
    sim_hh = torch.mm(z_high, z_high.t())
    sim_lh = torch.mm(z_low, z_high.t())

    eye_l = torch.eye(sim_ll.shape[0], device=sim_ll.device)
    eye_h = torch.eye(sim_hh.shape[0], device=sim_hh.device)
    sim_ll = sim_ll * (1 - eye_l)
    sim_hh = sim_hh * (1 - eye_h)

    return (-sim_ll.mean() - sim_hh.mean() + sim_lh.mean())


def total_variation(p: torch.Tensor):
    return torch.mean(torch.abs(p[:, 1:] - p[:, :-1]))


# --------------------------------
# 8) FRAME-WISE RECONSTRUCTION
# --------------------------------
def overlap_add_series(T: int, starts: List[int], win_series: List[np.ndarray]) -> np.ndarray:
    acc = np.zeros((T,), dtype=np.float32)
    cnt = np.zeros((T,), dtype=np.float32)
    for st, wseq in zip(starts, win_series):
        W = len(wseq)
        ed = min(T, st + W)
        seg = wseq[:(ed - st)]
        acc[st:ed] += seg
        cnt[st:ed] += 1.0
    return acc / (cnt + 1e-8)


@torch.no_grad()
def infer_one_trial_framewise(model: nn.Module, ds_one: TrialWindowDataset, cfg: Dict, sub: str):
    model.eval()
    loader = torch.utils.data.DataLoader(
        ds_one, batch_size=cfg["batch_size"], shuffle=False, collate_fn=collate_fn
    )

    device = cfg["device"]
    all_starts, all_pred_seq, all_pseudo_seq = [], [], []

    for X, P, keys, starts, _ in loader:
        X = X.to(device)
        P = P.to(device)
        _, _, elogit = model(X)
        prob = torch.sigmoid(elogit)

        for bi in range(prob.size(0)):
            if keys[bi] != sub:
                continue
            all_starts.append(int(starts[bi].item()))
            all_pred_seq.append(prob[bi].detach().cpu().numpy().astype(np.float32))
            all_pseudo_seq.append(P[bi].detach().cpu().numpy().astype(np.float32))

    X18_raw = ds_one.trials_raw[sub]
    T = X18_raw.shape[0]
    pred_frame = overlap_add_series(T, all_starts, all_pred_seq)
    pseudo_frame = overlap_add_series(T, all_starts, all_pseudo_seq)
    return pred_frame, pseudo_frame, X18_raw


# --------------------------------
# 9) COUNT ESTIMATION (AUTOCORR ONLY)
# --------------------------------
def _valid_freq_range(fs: int, min_bpm: float, max_bpm: float) -> Tuple[float, float]:
    fmin = (min_bpm / 60.0)
    fmax = (max_bpm / 60.0)
    fmax = min(fmax, fs / 2.0 - 1e-6)
    return fmin, max(fmin + 1e-6, fmax)


def estimate_count_autocorr_harmonic(
    x: np.ndarray,
    fs: int,
    min_bpm: float,
    max_bpm: float,
    h2_weight: float = 0.35,
    hhalf_weight: float = 0.15,
    fix_iters: int = 2,
    half_prefer_ratio: float = 0.92,   # ac(L/2) >= 0.92 * ac(L) 이면 L/2로 내림(=2배 카운트 방지)
    double_prefer_ratio: float = 1.08, # ac(2L) >= 1.08 * ac(L) 이면 2L로 올림(=1/2 카운트 방지)
    peak_margin: float = 0.02,         # 너무 미세한 차이엔 흔들리지 않게
) -> Tuple[float, float, float]:
    x = x.astype(np.float32)
    x = x - np.mean(x)
    T = len(x)
    if T < fs * 2:
        return 0.0, 0.0, 0.0

    ac = np.correlate(x, x, mode="full")[T-1:]
    ac = ac / (ac[0] + 1e-8)

    fmin, fmax = _valid_freq_range(fs, min_bpm, max_bpm)
    lag_max = int(np.floor(fs / fmin))
    lag_min = int(np.ceil(fs / fmax))
    lag_max = min(lag_max, T - 2)
    lag_min = max(1, min(lag_min, lag_max - 1))

    seg = ac[lag_min:lag_max+1]
    if len(seg) < 5:
        return 0.0, 0.0, 0.0

    def ac_at(l: int) -> float:
        if l <= 0 or l >= len(ac):
            return -1e9
        return float(ac[l])

    # 1) 후보 lag 선택: 기본 + (2배, 절반) harmonic 점수로 랭킹
    best_lag = lag_min
    best_comb = -1e18
    for lag in range(lag_min, lag_max + 1):
        base = ac_at(lag)
        if base < -0.3:  # 너무 안 좋은 곳 컷
            continue

        comb = base
        l2 = 2 * lag
        if l2 <= lag_max:
            comb += h2_weight * ac_at(l2)

        if (lag % 2 == 0):
            lhalf = lag // 2
            if lhalf >= lag_min:
                comb += hhalf_weight * ac_at(lhalf)

        if comb > best_comb:
            best_comb = comb
            best_lag = lag

    # 2) half/double 보정: fundamental 강제 선택
    L = int(best_lag)
    for _ in range(int(fix_iters)):
        aL = ac_at(L)

        # half 후보
        if L % 2 == 0:
            H = L // 2
            if H >= lag_min:
                aH = ac_at(H)
                # ac(H)가 ac(L)과 비슷 이상이면, L은 2배로 잡혔을 가능성
                if (aH >= half_prefer_ratio * aL - peak_margin):
                    L = H
                    continue

        # double 후보
        D = 2 * L
        if D <= lag_max:
            aD = ac_at(D)
            # ac(2L)가 더 강하면, L은 절반으로 잡혔을 가능성
            if (aD >= double_prefer_ratio * aL + peak_margin):
                L = D
                continue

        break

    # score는 “선택된 L의 품질”로 다시 계산
    meanv = float(np.mean(seg) + 1e-8)
    # fundamental 기준으로 harmonic을 같이 반영한 최종 score
    aL = ac_at(L)
    a2 = ac_at(2 * L) if 2 * L <= lag_max else 0.0
    ah = ac_at(L // 2) if (L % 2 == 0 and (L // 2) >= lag_min) else 0.0
    final_comb = aL + h2_weight * a2 + hhalf_weight * ah
    score = float(final_comb / meanv)

    period_sec = L / float(fs)
    duration_sec = T / float(fs)
    count = duration_sec / max(1e-8, period_sec)

    return float(count), float(score), float(period_sec)


def estimate_count_autocorr_only(x: np.ndarray, fs: int, cfg: Dict) -> Dict[str, float]:
    xs = moving_average_1d(x, win=cfg["count_smooth_win"])
    c, s, p0 = estimate_count_autocorr_harmonic(
        xs, fs, cfg["min_bpm"], cfg["max_bpm"],
        h2_weight=0.35,
        hhalf_weight=0.15,
        fix_iters=2,
        half_prefer_ratio=0.92,
        double_prefer_ratio=1.08,
        peak_margin=0.02
    )
    return {"count": c, "score": s, "period_sec": p0}


# --------------------------------
# 10) EVAL HELPERS (METRICS + LATENT SPEED)
# --------------------------------
def latent_speed_window(z_win: torch.Tensor) -> torch.Tensor:
    dz = z_win[:, :, 1:] - z_win[:, :, :-1]
    s = torch.norm(dz, dim=1).mean(dim=1)
    return s


@torch.no_grad()
def eval_fold(model: nn.Module, ds: TrialWindowDataset, cfg: Dict, activity: int, test_sub: str):
    model.eval()
    loader = torch.utils.data.DataLoader(
        ds, batch_size=cfg["batch_size"], shuffle=False, collate_fn=collate_fn
    )
    device = cfg["device"]

    all_pred_w, all_pseudo_w, all_latent, all_speed = [], [], [], []
    all_keys, all_starts = [], []
    all_pred_seq, all_pseudo_seq = [], []

    bce_sum, n_sum = 0.0, 0

    for X, P, keys, starts, _ in loader:
        X = X.to(device)
        P = P.to(device)

        z, _, elogit = model(X)
        prob = torch.sigmoid(elogit)

        bce = F.binary_cross_entropy(prob, P, reduction="mean")
        bce_sum += float(bce.item()) * X.size(0)
        n_sum += X.size(0)

        all_pred_w.append(prob.mean(dim=1).detach().cpu().numpy())
        all_pseudo_w.append(P.mean(dim=1).detach().cpu().numpy())
        all_latent.append(z.mean(dim=2).detach().cpu().numpy())
        all_speed.append(latent_speed_window(z).detach().cpu().numpy())

        for bi in range(prob.size(0)):
            all_keys.append(keys[bi])
            all_starts.append(int(starts[bi].item()))
            all_pred_seq.append(prob[bi].detach().cpu().numpy().astype(np.float32))
            all_pseudo_seq.append(P[bi].detach().cpu().numpy().astype(np.float32))

    pred_w = np.concatenate(all_pred_w, axis=0)
    pseudo_w = np.concatenate(all_pseudo_w, axis=0)
    latent = np.concatenate(all_latent, axis=0)
    speed = np.concatenate(all_speed, axis=0)

    corr = np.corrcoef(pred_w, pseudo_w)[0, 1] if len(pred_w) > 3 else 0.0

    n = len(pseudo_w)
    k = max(5, int(cfg["tb_frac"] * n))
    idx = np.argsort(pseudo_w)
    y = np.zeros(n, dtype=np.int64) - 1
    y[idx[:k]] = 0
    y[idx[-k:]] = 1
    mask = y >= 0
    try:
        auc = roc_auc_score(y[mask], pred_w[mask])
    except Exception:
        auc = 0.5

    X18_raw = ds.trials_raw[test_sub]
    T = X18_raw.shape[0]

    starts, pred_seqs, pseudo_seqs = [], [], []
    for key, st, pseq, qseq in zip(all_keys, all_starts, all_pred_seq, all_pseudo_seq):
        if key == test_sub:
            starts.append(st)
            pred_seqs.append(pseq)
            pseudo_seqs.append(qseq)

    pred_frame = overlap_add_series(T, starts, pred_seqs)
    pseudo_frame = overlap_add_series(T, starts, pseudo_seqs)

    count_info = estimate_count_autocorr_only(pred_frame, cfg["fs"], cfg)
    c_pred = float(count_info["count"])
    gt = float(COUNT_TABLE[activity][test_sub])
    mae = abs(c_pred - gt)
    mape = mae / (abs(gt) + 1e-8) * 100.0

    return {
        "bce": float(bce_sum / max(1, n_sum)),
        "corr": float(corr),
        "auc": float(auc),

        "count_pred": float(c_pred),
        "count_gt": float(gt),
        "mae": float(mae),
        "mape": float(mape),

        "count_score": float(count_info["score"]),
        "count_period_sec": float(count_info["period_sec"]),

        "latent": latent,
        "pseudo_w": pseudo_w,
        "pred_w": pred_w,
        "speed": speed,

        "pred_frame": pred_frame,
        "pseudo_frame": pseudo_frame,
        "X18_raw": X18_raw,
    }


# --------------------------------
# 11) TRAIN
# --------------------------------
def train_one_fold(train_ds: TrialWindowDataset, test_ds: TrialWindowDataset, cfg: Dict, activity: int, test_sub: str):
    device = cfg["device"]
    model = EventModel(latent_dim=64, hid=128).to(device)
    opt = torch.optim.Adam(model.parameters(), lr=cfg["lr"])

    train_loader = torch.utils.data.DataLoader(
        train_ds, batch_size=cfg["batch_size"], shuffle=True, collate_fn=collate_fn, drop_last=True
    )

    for ep in range(1, cfg["epochs"] + 1):
        model.train()

        loss_sum = recon_sum = bce_sum = con_sum = sp_sum = tv_sum = 0.0
        n_batches = 0

        for X, P, _, _, _ in train_loader:
            X = X.to(device)
            P = P.to(device)

            z, xhat, elogit = model(X)
            prob = torch.sigmoid(elogit)

            recon = F.mse_loss(xhat, X)
            bce = F.binary_cross_entropy(prob, P)
            con = contrast_top_bottom(z, P, tb_frac=cfg["tb_frac"])
            sp = prob.mean()
            tv = total_variation(prob)

            loss = (
                cfg["lambda_recon"] * recon +
                cfg["lambda_bce"] * bce +
                cfg["lambda_contrast"] * con +
                cfg["lambda_sparsity"] * sp +
                cfg["lambda_tv"] * tv
            )

            opt.zero_grad()
            loss.backward()
            opt.step()

            loss_sum += float(loss.item())
            recon_sum += float(recon.item())
            bce_sum += float(bce.item())
            con_sum += float(con.item())
            sp_sum += float(sp.item())
            tv_sum += float(tv.item())
            n_batches += 1

        if ep == 1 or ep % 10 == 0:
            print(
                f"[act={activity} | test_sub={test_sub} | ep={ep}] "
                f"Loss={loss_sum/n_batches:.4f} | "
                f"recon={recon_sum/n_batches:.4f} | bce={bce_sum/n_batches:.4f} | "
                f"contrast={con_sum/n_batches:.4f} | sparsity={sp_sum/n_batches:.4f} | tv={tv_sum/n_batches:.4f}"
            )

    metrics = eval_fold(model, test_ds, cfg, activity, test_sub)
    return model, metrics


# --------------------------------
# 12) VISUALIZATION (TOP/BOTTOM ONLY)
# --------------------------------
def _top_bottom_masks(x: np.ndarray, frac: float) -> Tuple[np.ndarray, np.ndarray]:
    x = x.reshape(-1)
    n = len(x)
    k = max(2, int(frac * n))
    idx = np.argsort(x)
    low = np.zeros(n, dtype=bool)
    high = np.zeros(n, dtype=bool)
    low[idx[:k]] = True
    high[idx[-k:]] = True
    return low, high


def plot_raw_with_top_bottom_shades(
    act: int,
    sub: str,
    fs: int,
    X18_raw: np.ndarray,
    series: np.ndarray,
    tb_frac: float,
    title_suffix: str,
    smooth_win: int = 9,
    alpha: float = 0.20,
):
    T = X18_raw.shape[0]
    t = np.arange(T, dtype=np.float32) / float(fs)
    raw = chest_acc_mag(X18_raw)

    s = moving_average_1d(series.astype(np.float32), win=smooth_win)
    low_mask, high_mask = _top_bottom_masks(s, tb_frac=tb_frac)  # type: ignore


def _top_bottom_masks(s: np.ndarray, tb_frac: float) -> Tuple[np.ndarray, np.ndarray]:
    s = s.reshape(-1)
    n = len(s)
    k = max(2, int(tb_frac * n))
    idx = np.argsort(s)
    low = np.zeros(n, dtype=bool)
    high = np.zeros(n, dtype=bool)
    low[idx[:k]] = True
    high[idx[-k:]] = True
    return low, high


def plot_raw_with_top_bottom_shades(
    act: int,
    sub: str,
    fs: int,
    X18_raw: np.ndarray,
    series: np.ndarray,
    tb_frac: float,
    title_suffix: str,
    smooth_win: int = 9,
    alpha: float = 0.20,
):
    T = X18_raw.shape[0]
    t = np.arange(T, dtype=np.float32) / float(fs)
    raw = chest_acc_mag(X18_raw)

    s = moving_average_1d(series.astype(np.float32), win=smooth_win)
    low_mask, high_mask = _top_bottom_masks(s, tb_frac)

    fig, ax = plt.subplots(1, 1, figsize=(18, 4))
    ax.plot(t, raw, lw=1.0)

    for a, b in mask_to_spans(low_mask):
        x0 = t[a]
        x1 = t[b] if b < T else t[-1]
        ax.axvspan(x0, x1, alpha=alpha, label="_nolegend_")

    for a, b in mask_to_spans(high_mask):
        x0 = t[a]
        x1 = t[b] if b < T else t[-1]
        ax.axvspan(x0, x1, alpha=alpha, hatch="///", label="_nolegend_")

    from matplotlib.patches import Patch
    handles = [
        Patch(alpha=alpha, label=f"steady: bottom {int(tb_frac*100)}%"),
        Patch(alpha=alpha, hatch="///", label=f"transition: top {int(tb_frac*100)}%"),
    ]
    ax.legend(handles=handles, loc="upper right")
    ax.set_title(f"act={act} | {sub} | {title_suffix}")
    ax.set_xlabel("time (sec)")
    ax.set_ylabel("chest_acc_mag")
    ax.grid(True, alpha=0.25)
    plt.tight_layout()
    plt.show()


def plot_latent_speed_boxplot(speed: np.ndarray, pseudo_w: np.ndarray, tb_frac: float, title: str):
    n = len(pseudo_w)
    k = max(2, int(tb_frac * n))
    idx = np.argsort(pseudo_w.reshape(-1))
    low = idx[:k]
    high = idx[-k:]

    data = [speed[low], speed[high]]
    plt.figure(figsize=(5.5, 4))
    plt.boxplot(data, labels=[f"steady\n(bottom {int(tb_frac*100)}%)", f"transition\n(top {int(tb_frac*100)}%)"])
    plt.title(title)
    plt.ylabel("latent speed (mean ||z_t - z_{t-1}||)")
    plt.grid(True, alpha=0.25)
    plt.tight_layout()
    plt.show()


def plot_count_scatter(preds: List[float], gts: List[float], title: str):
    plt.figure(figsize=(5.2, 5.2))
    plt.scatter(gts, preds, s=22, alpha=0.8)
    mn = min(min(gts), min(preds))
    mx = max(max(gts), max(preds))
    plt.plot([mn, mx], [mn, mx])
    plt.title(title)
    plt.xlabel("GT count")
    plt.ylabel("Pred count")
    plt.grid(True, alpha=0.25)
    plt.tight_layout()
    plt.show()


# --------------------------------
# 13) RUN (PER-ACT LOSO)
# --------------------------------
def run_all(cfg: Dict):
    set_seed(cfg["seed"])

    overall_maes, overall_mapes = [], []
    per_act_summary = {}

    for act in cfg["activities"]:
        print("=" * 80)
        print(f"[BUILD] activity={act}")
        trials = build_trials_for_activity(cfg["data_dir"], act, cfg["subjects"])
        print(f"  trials: {len(trials)} subjects")

        keys = sorted(list(trials.keys()), key=lambda x: int(x.replace("subject", "")))
        fold_mae, fold_mape = [], []
        fold_bce, fold_corr, fold_auc = [], [], []

        count_preds, count_gts = [], []

        last_model = None
        last_test_sub = None
        last_metrics = None

        for test_sub in keys:
            train_trials = {k: v for k, v in trials.items() if k != test_sub}
            test_trials = {test_sub: trials[test_sub]}

            train_ds = TrialWindowDataset(train_trials, cfg)
            test_ds = TrialWindowDataset(test_trials, cfg)

            model, metrics = train_one_fold(train_ds, test_ds, cfg, act, test_sub)
            last_model = model
            last_test_sub = test_sub
            last_metrics = metrics

            fold_mae.append(metrics["mae"])
            fold_mape.append(metrics["mape"])
            fold_bce.append(metrics["bce"])
            fold_corr.append(metrics["corr"])
            fold_auc.append(metrics["auc"])

            count_preds.append(metrics["count_pred"])
            count_gts.append(metrics["count_gt"])

            print(
                f"[EVAL act={act} | test_sub={test_sub}] "
                f"pseudo: BCE={metrics['bce']:.4f}, corr={metrics['corr']:.4f}, AUC(top/bot)={metrics['auc']:.4f} | "
                f"count(score={metrics['count_score']:.2f}, period={metrics['count_period_sec']:.3f}s): "
                f"pred={metrics['count_pred']:.2f}, gt={metrics['count_gt']:.2f}, "
                f"MAE={metrics['mae']:.2f}, MAPE={metrics['mape']:.2f}%"
            )

        per_act_summary[act] = {
            "MAE": float(np.mean(fold_mae)) if len(fold_mae) else float("nan"),
            "MAPE": float(np.mean(fold_mape)) if len(fold_mape) else float("nan"),
            "pseudo_BCE": float(np.mean(fold_bce)) if len(fold_bce) else float("nan"),
            "pseudo_corr": float(np.mean(fold_corr)) if len(fold_corr) else float("nan"),
            "pseudo_AUC": float(np.mean(fold_auc)) if len(fold_auc) else float("nan"),
        }

        overall_maes += fold_mae
        overall_mapes += fold_mape

        if last_model is not None and last_test_sub is not None and last_metrics is not None:
            sub = last_test_sub
            one_trials = {sub: trials[sub]}
            one_ds = TrialWindowDataset(one_trials, cfg)
            pred_frame, pseudo_frame, X18_raw = infer_one_trial_framewise(last_model, one_ds, cfg, sub)

            viz_tb_frac = cfg["tb_frac"]
            viz_smooth = cfg["count_smooth_win"]
            viz_alpha = 0.20

            plot_raw_with_top_bottom_shades(
                act=act,
                sub=sub,
                fs=cfg["fs"],
                X18_raw=X18_raw,
                series=pseudo_frame,
                tb_frac=viz_tb_frac,
                title_suffix="raw + pseudo top/bottom spans",
                smooth_win=viz_smooth,
                alpha=viz_alpha,
            )

            plot_raw_with_top_bottom_shades(
                act=act,
                sub=sub,
                fs=cfg["fs"],
                X18_raw=X18_raw,
                series=pred_frame,
                tb_frac=viz_tb_frac,
                title_suffix="raw + model pred top/bottom spans",
                smooth_win=viz_smooth,
                alpha=viz_alpha,
            )

            plot_latent_speed_boxplot(
                speed=last_metrics["speed"],
                pseudo_w=last_metrics["pseudo_w"],
                tb_frac=viz_tb_frac,
                title=f"act={act} | latent speed (steady vs transition)",
            )

            plot_count_scatter(
                preds=count_preds,
                gts=count_gts,
                title=f"act={act} | count pred vs GT (LOSO)",
            )

    print("\n" + "=" * 80)
    print("[SUMMARY] per-activity (LOSO mean)")
    for act, s in per_act_summary.items():
        print(
            f"  act={act} | MAE={s['MAE']:.2f} | MAPE={s['MAPE']:.2f}% | "
            f"pseudo(BCE={s['pseudo_BCE']:.4f}, corr={s['pseudo_corr']:.4f}, AUC={s['pseudo_AUC']:.4f})"
        )

    overall_mae = float(np.mean(overall_maes)) if len(overall_maes) else float("nan")
    overall_mape = float(np.mean(overall_mapes)) if len(overall_mapes) else float("nan")
    print(f"\n[OVERALL] MAE={overall_mae:.2f} | MAPE={overall_mape:.2f}% over {len(overall_maes)} folds")


# --------------------------------
# 14) RUN
# --------------------------------
if __name__ == "__main__":
    run_all(CONFIG)
# Out:
# ================================================================================
# [BUILD] activity=6
#   trials: 10 subjects
# [act=6 | test_sub=subject1 | ep=1] Loss=1.2114 | recon=0.6574 | bce=0.6741 | contrast=-0.7454 | sparsity=0.5042 | tv=0.0134
# [act=6 | test_sub=subject1 | ep=10] Loss=0.2667 | recon=0.1484 | bce=0.6174 | contrast=-2.0239 | sparsity=0.5091 | tv=0.0314
# [act=6 | test_sub=subject1 | ep=20] Loss=0.1473 | recon=0.1181 | bce=0.6055 | contrast=-2.2838 | sparsity=0.5075 | tv=0.0368
# [act=6 | test_sub=subject1 | ep=30] Loss=0.0699 | recon=0.1004 | bce=0.5980 | contrast=-2.4629 | sparsity=0.5101 | tv=0.0424
# [act=6 | test_sub=subject1 | ep=40] Loss=-0.0126 | recon=0.0953 | bce=0.5938 | contrast=-2.7078 | sparsity=0.5089 | tv=0.0445
# [act=6 | test_sub=subject1 | ep=50] Loss=-0.0199 | recon=0.0832 | bce=0.5847 | contrast=-2.6652 | sparsity=0.5108 | tv=0.0478
# [EVAL act=6 | test_sub=subject1] pseudo: BCE=0.6051, corr=0.8868, AUC(top/bot)=1.0000 | count(score=-38.88, period=3.000s): pred=20.48, gt=21.00, MAE=0.52, MAPE=2.48%
# [act=6 | test_sub=subject2 | ep=1] Loss=1.1919 | recon=0.6601 | bce=0.6701 | contrast=-0.8069 | sparsity=0.5024 | tv=0.0165
# [act=6 | test_sub=subject2 | ep=10] Loss=0.2764 | recon=0.1513 | bce=0.6206 | contrast=-2.0082 | sparsity=0.5082 | tv=0.0264
# [act=6 | test_sub=subject2 | ep=20] Loss=0.1219 | recon=0.1219 | bce=0.6056 | contrast=-2.3816 | sparsity=0.5098 | tv=0.0345
# [act=6 | test_sub=subject2 | ep=30] Loss=0.0067 | recon=0.1022 | bce=0.5919 | contrast=-2.6639 | sparsity=0.5173 | tv=0.0416
# [act=6 | test_sub=subject2 | ep=40] Loss=-0.0325 | recon=0.0953 | bce=0.5880 | contrast=-2.7588 | sparsity=0.5135 | tv=0.0457
# [act=6 | test_sub=subject2 | ep=50] Loss=-0.0324 | recon=0.0823 | bce=0.5860 | contrast=-2.7116 | sparsity=0.5164 | tv=0.0479
# [EVAL act=6 | test_sub=subject2] pseudo: BCE=0.6706, corr=0.3761, AUC(top/bot)=0.8320 | count(score=-12.18, period=3.500s): pred=18.14, gt=19.00, MAE=0.86, MAPE=4.54%
# [act=6 | test_sub=subject3 | ep=1] Loss=1.2177 | recon=0.6645 | bce=0.6731 | contrast=-0.7512 | sparsity=0.5141 | tv=0.0136
# [act=6 | test_sub=subject3 | ep=10] Loss=0.2987 | recon=0.1608 | bce=0.6203 | contrast=-1.9682 | sparsity=0.5133 | tv=0.0275
# [act=6 | test_sub=subject3 | ep=20] Loss=0.1704 | recon=0.1195 | bce=0.6105 | contrast=-2.2302 | sparsity=0.5137 | tv=0.0331
# [act=6 | test_sub=subject3 | ep=30] Loss=0.1042 | recon=0.1012 | bce=0.5967 | contrast=-2.3513 | sparsity=0.5181 | tv=0.0403
# [act=6 | test_sub=subject3 | ep=40] Loss=-0.0015 | recon=0.0934 | bce=0.5919 | contrast=-2.6631 | sparsity=0.5168 | tv=0.0435
# [act=6 | test_sub=subject3 | ep=50] Loss=-0.0404 | recon=0.0871 | bce=0.5888 | contrast=-2.7616 | sparsity=0.5144 | tv=0.0462
# [EVAL act=6 | test_sub=subject3] pseudo: BCE=0.6041, corr=0.7775, AUC(top/bot)=0.9792 | count(score=679.16, period=3.160s): pred=20.42, gt=21.00, MAE=0.58, MAPE=2.77%
# [act=6 | test_sub=subject4 | ep=1] Loss=1.1715 | recon=0.6255 | bce=0.6739 | contrast=-0.7689 | sparsity=0.4982 | tv=0.0154
# [act=6 | test_sub=subject4 | ep=10] Loss=0.2899 | recon=0.1514 | bce=0.6175 | contrast=-1.9581 | sparsity=0.5136 | tv=0.0286
# [act=6 | test_sub=subject4 | ep=20] Loss=0.1541 | recon=0.1080 | bce=0.6053 | contrast=-2.2281 | sparsity=0.5083 | tv=0.0375
# [act=6 | test_sub=subject4 | ep=30] Loss=0.0916 | recon=0.0960 | bce=0.5929 | contrast=-2.3639 | sparsity=0.5169 | tv=0.0420
# [act=6 | test_sub=subject4 | ep=40] Loss=0.0406 | recon=0.0936 | bce=0.5903 | contrast=-2.5194 | sparsity=0.5165 | tv=0.0460
# [act=6 | test_sub=subject4 | ep=50] Loss=0.0045 | recon=0.0947 | bce=0.5888 | contrast=-2.6386 | sparsity=0.5167 | tv=0.0455
# [EVAL act=6 | test_sub=subject4] pseudo: BCE=0.6064, corr=0.8421, AUC(top/bot)=0.9911 | count(score=-10.17, period=3.320s): pred=20.05, gt=20.00, MAE=0.05, MAPE=0.24%
# [act=6 | test_sub=subject5 | ep=1] Loss=1.2317 | recon=0.6260 | bce=0.6761 | contrast=-0.5785 | sparsity=0.5012 | tv=0.0145
# [act=6 | test_sub=subject5 | ep=10] Loss=0.3095 | recon=0.1514 | bce=0.6260 | contrast=-1.9146 | sparsity=0.5041 | tv=0.0283
# [act=6 | test_sub=subject5 | ep=20] Loss=0.1695 | recon=0.1176 | bce=0.6144 | contrast=-2.2388 | sparsity=0.5095 | tv=0.0363
# [act=6 | test_sub=subject5 | ep=30] Loss=0.0643 | recon=0.1143 | bce=0.6051 | contrast=-2.5518 | sparsity=0.5127 | tv=0.0395
# [act=6 | test_sub=subject5 | ep=40] Loss=0.0348 | recon=0.0941 | bce=0.6038 | contrast=-2.5795 | sparsity=0.5101 | tv=0.0436
# [act=6 | test_sub=subject5 | ep=50] Loss=-0.0534 | recon=0.0783 | bce=0.5899 | contrast=-2.7801 | sparsity=0.5146 | tv=0.0477
# [EVAL act=6 | test_sub=subject5] pseudo: BCE=0.5741, corr=0.9501, AUC(top/bot)=1.0000 | count(score=90.97, period=2.820s): pred=19.61, gt=20.00, MAE=0.39, MAPE=1.95%
# [act=6 | test_sub=subject6 | ep=1] Loss=1.1641 | recon=0.6316 | bce=0.6659 | contrast=-0.7996 | sparsity=0.5162 | tv=0.0164
# [act=6 | test_sub=subject6 | ep=10] Loss=0.2809 | recon=0.1428 | bce=0.6190 | contrast=-1.9585 | sparsity=0.5042 | tv=0.0293
# [act=6 | test_sub=subject6 | ep=20] Loss=0.1350 | recon=0.1083 | bce=0.6007 | contrast=-2.2817 | sparsity=0.5134 | tv=0.0395
# [act=6 | test_sub=subject6 | ep=30] Loss=0.0507 | recon=0.1031 | bce=0.5980 | contrast=-2.5352 | sparsity=0.5082 | tv=0.0422
# [act=6 | test_sub=subject6 | ep=40] Loss=-0.0283 | recon=0.0844 | bce=0.5876 | contrast=-2.7072 | sparsity=0.5110 | tv=0.0482
# [act=6 | test_sub=subject6 | ep=50] Loss=-0.0631 | recon=0.0812 | bce=0.5841 | contrast=-2.8033 | sparsity=0.5156 | tv=0.0475
# [EVAL act=6 | test_sub=subject6] pseudo: BCE=0.6413, corr=0.4398, AUC(top/bot)=0.8304 | count(score=-31.32, period=2.240s): pred=19.66, gt=20.00, MAE=0.34, MAPE=1.70%
# [act=6 | test_sub=subject7 | ep=1] Loss=1.1998 | recon=0.6349 | bce=0.6757 | contrast=-0.7125 | sparsity=0.5019 | tv=0.0126
# [act=6 | test_sub=subject7 | ep=10] Loss=0.3045 | recon=0.1543 | bce=0.6207 | contrast=-1.9279 | sparsity=0.5102 | tv=0.0290
# [act=6 | test_sub=subject7 | ep=20] Loss=0.1700 | recon=0.1159 | bce=0.6066 | contrast=-2.2033 | sparsity=0.5062 | tv=0.0363
# [act=6 | test_sub=subject7 | ep=30] Loss=0.0590 | recon=0.1037 | bce=0.5970 | contrast=-2.5077 | sparsity=0.5124 | tv=0.0406
# [act=6 | test_sub=subject7 | ep=40] Loss=0.0074 | recon=0.0901 | bce=0.5948 | contrast=-2.6305 | sparsity=0.5138 | tv=0.0444
# [act=6 | test_sub=subject7 | ep=50] Loss=-0.0335 | recon=0.0835 | bce=0.5820 | contrast=-2.7056 | sparsity=0.5151 | tv=0.0486
# [EVAL act=6 | test_sub=subject7] pseudo: BCE=0.6188, corr=0.8651, AUC(top/bot)=0.9913 | count(score=-10.17, period=3.240s): pred=18.96, gt=20.00, MAE=1.04, MAPE=5.19%
# [act=6 | test_sub=subject8 | ep=1] Loss=1.1681 | recon=0.6121 | bce=0.6720 | contrast=-0.7372 | sparsity=0.5132 | tv=0.0131
# [act=6 | test_sub=subject8 | ep=10] Loss=0.2772 | recon=0.1445 | bce=0.6117 | contrast=-1.9575 | sparsity=0.5086 | tv=0.0321
# [act=6 | test_sub=subject8 | ep=20] Loss=0.1189 | recon=0.1135 | bce=0.6003 | contrast=-2.3536 | sparsity=0.5150 | tv=0.0405
# [act=6 | test_sub=subject8 | ep=30] Loss=-0.0173 | recon=0.0916 | bce=0.5899 | contrast=-2.6990 | sparsity=0.5098 | tv=0.0446
# [act=6 | test_sub=subject8 | ep=40] Loss=-0.0050 | recon=0.0841 | bce=0.5918 | contrast=-2.6407 | sparsity=0.5127 | tv=0.0443
# [act=6 | test_sub=subject8 | ep=50] Loss=-0.0784 | recon=0.0700 | bce=0.5823 | contrast=-2.8120 | sparsity=0.5159 | tv=0.0484
# [EVAL act=6 | test_sub=subject8] pseudo: BCE=0.6251, corr=0.7957, AUC(top/bot)=0.9758 | count(score=-25.40, period=2.180s): pred=19.73, gt=21.00, MAE=1.27, MAPE=6.03%
# [act=6 | test_sub=subject9 | ep=1] Loss=1.2329 | recon=0.6628 | bce=0.6734 | contrast=-0.6954 | sparsity=0.5111 | tv=0.0152
# [act=6 | test_sub=subject9 | ep=10] Loss=0.2855 | recon=0.1554 | bce=0.6196 | contrast=-1.9859 | sparsity=0.5015 | tv=0.0299
# [act=6 | test_sub=subject9 | ep=20] Loss=0.1281 | recon=0.1239 | bce=0.6045 | contrast=-2.3691 | sparsity=0.5124 | tv=0.0393
# [act=6 | test_sub=subject9 | ep=30] Loss=0.0536 | recon=0.1027 | bce=0.5968 | contrast=-2.5239 | sparsity=0.5140 | tv=0.0421
# [act=6 | test_sub=subject9 | ep=40] Loss=0.0382 | recon=0.0971 | bce=0.5910 | contrast=-2.5409 | sparsity=0.5165 | tv=0.0452
# [act=6 | test_sub=subject9 | ep=50] Loss=-0.0529 | recon=0.0860 | bce=0.5856 | contrast=-2.7899 | sparsity=0.5133 | tv=0.0486
# [EVAL act=6 | test_sub=subject9] pseudo: BCE=0.6281, corr=0.7681, AUC(top/bot)=0.9649 | count(score=171.53, period=2.760s): pred=20.78, gt=21.00, MAE=0.22, MAPE=1.07%
# [act=6 | test_sub=subject10 | ep=1] Loss=1.2062 | recon=0.6518 | bce=0.6723 | contrast=-0.7315 | sparsity=0.4940 | tv=0.0136
# [act=6 | test_sub=subject10 | ep=10] Loss=0.2835 | recon=0.1591 | bce=0.6135 | contrast=-1.9879 | sparsity=0.5068 | tv=0.0294
# [act=6 | test_sub=subject10 | ep=20] Loss=0.1471 | recon=0.1181 | bce=0.5995 | contrast=-2.2653 | sparsity=0.5083 | tv=0.0371
# [act=6 | test_sub=subject10 | ep=30] Loss=0.0807 | recon=0.1068 | bce=0.5954 | contrast=-2.4348 | sparsity=0.5033 | tv=0.0416
# [act=6 | test_sub=subject10 | ep=40] Loss=0.0077 | recon=0.0900 | bce=0.5868 | contrast=-2.5983 | sparsity=0.5066 | tv=0.0449
# [act=6 | test_sub=subject10 | ep=50] Loss=0.0123 | recon=0.0894 | bce=0.5942 | contrast=-2.6016 | sparsity=0.5025 | tv=0.0436
# [EVAL act=6 | test_sub=subject10] pseudo: BCE=0.6569, corr=0.4741, AUC(top/bot)=0.8476 | count(score=55.18, period=2.640s): pred=18.62, gt=20.00, MAE=1.38, MAPE=6.89%
# /tmp/ipython-input-1334207235.py:832: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data, labels=[f"steady\n(bottom {int(tb_frac*100)}%)", f"transition\n(top {int(tb_frac*100)}%)"])
# ================================================================================
# [BUILD] activity=7
#   trials: 10 subjects
# [act=7 | test_sub=subject1 | ep=1] Loss=1.2256 | recon=0.6902 | bce=0.6669 | contrast=-0.7965 | sparsity=0.5185 | tv=0.0182
# [act=7 | test_sub=subject1 | ep=10] Loss=0.3025 | recon=0.1822 | bce=0.6154 | contrast=-2.0154 | sparsity=0.5153 | tv=0.0325
# [act=7 | test_sub=subject1 | ep=20] Loss=0.1542 | recon=0.1388 | bce=0.5965 | contrast=-2.3098 | sparsity=0.5197 | tv=0.0397
# [act=7 | test_sub=subject1 | ep=30] Loss=0.0589 | recon=0.1153 | bce=0.5863 | contrast=-2.5199 | sparsity=0.5236 | tv=0.0426
# [act=7 | test_sub=subject1 | ep=40] Loss=0.0356 | recon=0.1159 | bce=0.5956 | contrast=-2.6339 | sparsity=0.5330 | tv=0.0385
# [act=7 | test_sub=subject1 | ep=50] Loss=-0.0403 | recon=0.0871 | bce=0.5796 | contrast=-2.7361 | sparsity=0.5245 | tv=0.0448
# [EVAL act=7 | test_sub=subject1] pseudo: BCE=0.6592, corr=0.5891, AUC(top/bot)=0.9253 | count(score=-27.32, period=3.000s): pred=20.48, gt=20.00, MAE=0.48, MAPE=2.40%
# [act=7 | test_sub=subject2 | ep=1] Loss=1.1872 | recon=0.6899 | bce=0.6667 | contrast=-0.9223 | sparsity=0.5171 | tv=0.0199
# [act=7 | test_sub=subject2 | ep=10] Loss=0.3117 | recon=0.1795 | bce=0.6223 | contrast=-1.9976 | sparsity=0.5206 | tv=0.0254
# [act=7 | test_sub=subject2 | ep=20] Loss=0.1832 | recon=0.1425 | bce=0.5999 | contrast=-2.2399 | sparsity=0.5272 | tv=0.0366
# [act=7 | test_sub=subject2 | ep=30] Loss=0.0674 | recon=0.1242 | bce=0.5922 | contrast=-2.5393 | sparsity=0.5246 | tv=0.0395
# [act=7 | test_sub=subject2 | ep=40] Loss=-0.0146 | recon=0.0996 | bce=0.5822 | contrast=-2.7040 | sparsity=0.5309 | tv=0.0429
# [act=7 | test_sub=subject2 | ep=50] Loss=-0.0695 | recon=0.0814 | bce=0.5752 | contrast=-2.8011 | sparsity=0.5245 | tv=0.0462
# [EVAL act=7 | test_sub=subject2] pseudo: BCE=0.6560, corr=0.4410, AUC(top/bot)=0.8447 | count(score=-12.97, period=3.380s): pred=19.69, gt=20.00, MAE=0.31, MAPE=1.54%
# [act=7 | test_sub=subject3 | ep=1] Loss=1.2520 | recon=0.6897 | bce=0.6622 | contrast=-0.6945 | sparsity=0.5216 | tv=0.0207
# [act=7 | test_sub=subject3 | ep=10] Loss=0.3395 | recon=0.1751 | bce=0.6191 | contrast=-1.8776 | sparsity=0.5115 | tv=0.0310
# [act=7 | test_sub=subject3 | ep=20] Loss=0.1887 | recon=0.1315 | bce=0.5999 | contrast=-2.1822 | sparsity=0.5225 | tv=0.0369
# [act=7 | test_sub=subject3 | ep=30] Loss=0.1109 | recon=0.1261 | bce=0.5962 | contrast=-2.4120 | sparsity=0.5216 | tv=0.0396
# [act=7 | test_sub=subject3 | ep=40] Loss=0.0205 | recon=0.1133 | bce=0.5942 | contrast=-2.6620 | sparsity=0.5162 | tv=0.0419
# [act=7 | test_sub=subject3 | ep=50] Loss=-0.0452 | recon=0.0894 | bce=0.5864 | contrast=-2.7795 | sparsity=0.5198 | tv=0.0447
# [EVAL act=7 | test_sub=subject3] pseudo: BCE=0.6046, corr=0.7657, AUC(top/bot)=1.0000 | count(score=-9.94, period=3.400s): pred=19.88, gt=20.00, MAE=0.12, MAPE=0.62%
# [act=7 | test_sub=subject4 | ep=1] Loss=1.2315 | recon=0.6755 | bce=0.6646 | contrast=-0.7235 | sparsity=0.5226 | tv=0.0195
# [act=7 | test_sub=subject4 | ep=10] Loss=0.3138 | recon=0.1722 | bce=0.6182 | contrast=-1.9538 | sparsity=0.5171 | tv=0.0308
# [act=7 | test_sub=subject4 | ep=20] Loss=0.1440 | recon=0.1317 | bce=0.5977 | contrast=-2.3244 | sparsity=0.5224 | tv=0.0372
# [act=7 | test_sub=subject4 | ep=30] Loss=0.0619 | recon=0.1226 | bce=0.5939 | contrast=-2.5526 | sparsity=0.5162 | tv=0.0398
# [act=7 | test_sub=subject4 | ep=40] Loss=0.0396 | recon=0.1127 | bce=0.5851 | contrast=-2.5750 | sparsity=0.5292 | tv=0.0429
# [act=7 | test_sub=subject4 | ep=50] Loss=0.0130 | recon=0.0951 | bce=0.5861 | contrast=-2.6040 | sparsity=0.5225 | tv=0.0429
# [EVAL act=7 | test_sub=subject4] pseudo: BCE=0.6031, corr=0.8525, AUC(top/bot)=1.0000 | count(score=-11.89, period=3.240s): pred=20.23, gt=20.00, MAE=0.23, MAPE=1.14%
# [act=7 | test_sub=subject5 | ep=1] Loss=1.2320 | recon=0.6719 | bce=0.6732 | contrast=-0.7349 | sparsity=0.5208 | tv=0.0161
# [act=7 | test_sub=subject5 | ep=10] Loss=0.3227 | recon=0.1861 | bce=0.6166 | contrast=-1.9657 | sparsity=0.5165 | tv=0.0324
# [act=7 | test_sub=subject5 | ep=20] Loss=0.1586 | recon=0.1351 | bce=0.6022 | contrast=-2.2991 | sparsity=0.5173 | tv=0.0376
# [act=7 | test_sub=subject5 | ep=30] Loss=0.0877 | recon=0.1334 | bce=0.5913 | contrast=-2.4963 | sparsity=0.5171 | tv=0.0419
# [act=7 | test_sub=subject5 | ep=40] Loss=0.0187 | recon=0.1160 | bce=0.5957 | contrast=-2.6838 | sparsity=0.5215 | tv=0.0391
# [act=7 | test_sub=subject5 | ep=50] Loss=-0.0284 | recon=0.0969 | bce=0.5877 | contrast=-2.7597 | sparsity=0.5320 | tv=0.0427
# [EVAL act=7 | test_sub=subject5] pseudo: BCE=0.6128, corr=0.8439, AUC(top/bot)=1.0000 | count(score=-270.19, period=2.880s): pred=19.92, gt=20.00, MAE=0.08, MAPE=0.42%
# [act=7 | test_sub=subject6 | ep=1] Loss=1.2268 | recon=0.6755 | bce=0.6736 | contrast=-0.7568 | sparsity=0.5060 | tv=0.0176
# [act=7 | test_sub=subject6 | ep=10] Loss=0.3313 | recon=0.1723 | bce=0.6204 | contrast=-1.8968 | sparsity=0.5067 | tv=0.0314
# [act=7 | test_sub=subject6 | ep=20] Loss=0.1620 | recon=0.1343 | bce=0.5994 | contrast=-2.2772 | sparsity=0.5199 | tv=0.0376
# [act=7 | test_sub=subject6 | ep=30] Loss=0.0593 | recon=0.1161 | bce=0.5940 | contrast=-2.5435 | sparsity=0.5215 | tv=0.0399
# [act=7 | test_sub=subject6 | ep=40] Loss=-0.0227 | recon=0.0956 | bce=0.5867 | contrast=-2.7258 | sparsity=0.5216 | tv=0.0420
# [act=7 | test_sub=subject6 | ep=50] Loss=-0.0311 | recon=0.0853 | bce=0.5827 | contrast=-2.7091 | sparsity=0.5239 | tv=0.0445
# [EVAL act=7 | test_sub=subject6] pseudo: BCE=0.6399, corr=0.6521, AUC(top/bot)=0.9453 | count(score=-22.96, period=2.180s): pred=19.26, gt=20.00, MAE=0.74, MAPE=3.72%
# [act=7 | test_sub=subject7 | ep=1] Loss=1.2251 | recon=0.6832 | bce=0.6682 | contrast=-0.7815 | sparsity=0.5225 | tv=0.0184
# [act=7 | test_sub=subject7 | ep=10] Loss=0.3168 | recon=0.1760 | bce=0.6156 | contrast=-1.9520 | sparsity=0.5239 | tv=0.0303
# [act=7 | test_sub=subject7 | ep=20] Loss=0.1252 | recon=0.1385 | bce=0.5975 | contrast=-2.4087 | sparsity=0.5221 | tv=0.0368
# [act=7 | test_sub=subject7 | ep=30] Loss=0.0779 | recon=0.1250 | bce=0.5949 | contrast=-2.5154 | sparsity=0.5248 | tv=0.0378
# [act=7 | test_sub=subject7 | ep=40] Loss=-0.0145 | recon=0.1054 | bce=0.5859 | contrast=-2.7309 | sparsity=0.5263 | tv=0.0414
# [act=7 | test_sub=subject7 | ep=50] Loss=-0.0341 | recon=0.0918 | bce=0.5827 | contrast=-2.7401 | sparsity=0.5230 | tv=0.0441
# [EVAL act=7 | test_sub=subject7] pseudo: BCE=0.6550, corr=0.1678, AUC(top/bot)=0.7007 | count(score=-79.95, period=2.740s): pred=20.18, gt=20.00, MAE=0.18, MAPE=0.91%
# [act=7 | test_sub=subject8 | ep=1] Loss=1.2530 | recon=0.7095 | bce=0.6684 | contrast=-0.7741 | sparsity=0.5196 | tv=0.0173
# [act=7 | test_sub=subject8 | ep=10] Loss=0.3076 | recon=0.1822 | bce=0.6170 | contrast=-2.0072 | sparsity=0.5203 | tv=0.0328
# [act=7 | test_sub=subject8 | ep=20] Loss=0.1493 | recon=0.1439 | bce=0.5994 | contrast=-2.3530 | sparsity=0.5201 | tv=0.0393
# [act=7 | test_sub=subject8 | ep=30] Loss=0.0703 | recon=0.1271 | bce=0.5951 | contrast=-2.5478 | sparsity=0.5211 | tv=0.0412
# [act=7 | test_sub=subject8 | ep=40] Loss=-0.0019 | recon=0.1033 | bce=0.5910 | contrast=-2.6943 | sparsity=0.5182 | tv=0.0426
# [act=7 | test_sub=subject8 | ep=50] Loss=-0.0663 | recon=0.0864 | bce=0.5811 | contrast=-2.8257 | sparsity=0.5233 | tv=0.0458
# [EVAL act=7 | test_sub=subject8] pseudo: BCE=0.6214, corr=0.7184, AUC(top/bot)=0.9546 | count(score=-17.73, period=1.500s): pred=40.28, gt=19.00, MAE=21.28, MAPE=112.00%
# [act=7 | test_sub=subject9 | ep=1] Loss=1.2177 | recon=0.6617 | bce=0.6667 | contrast=-0.7235 | sparsity=0.5117 | tv=0.0202
# [act=7 | test_sub=subject9 | ep=10] Loss=0.3134 | recon=0.1659 | bce=0.6186 | contrast=-1.9377 | sparsity=0.5199 | tv=0.0307
# [act=7 | test_sub=subject9 | ep=20] Loss=0.1975 | recon=0.1371 | bce=0.6020 | contrast=-2.1786 | sparsity=0.5200 | tv=0.0396
# [act=7 | test_sub=subject9 | ep=30] Loss=0.1125 | recon=0.1145 | bce=0.5936 | contrast=-2.3644 | sparsity=0.5280 | tv=0.0407
# [act=7 | test_sub=subject9 | ep=40] Loss=0.0438 | recon=0.1038 | bce=0.5928 | contrast=-2.5579 | sparsity=0.5317 | tv=0.0409
# [act=7 | test_sub=subject9 | ep=50] Loss=-0.0236 | recon=0.0912 | bce=0.5824 | contrast=-2.7048 | sparsity=0.5269 | tv=0.0439
# [EVAL act=7 | test_sub=subject9] pseudo: BCE=0.5998, corr=0.9079, AUC(top/bot)=1.0000 | count(score=669.52, period=2.920s): pred=19.64, gt=19.00, MAE=0.64, MAPE=3.35%
# [act=7 | test_sub=subject10 | ep=1] Loss=1.1992 | recon=0.6781 | bce=0.6724 | contrast=-0.8538 | sparsity=0.5080 | tv=0.0166
# [act=7 | test_sub=subject10 | ep=10] Loss=0.3039 | recon=0.1779 | bce=0.6183 | contrast=-2.0015 | sparsity=0.5114 | tv=0.0295
# [act=7 | test_sub=subject10 | ep=20] Loss=0.1607 | recon=0.1437 | bce=0.6000 | contrast=-2.3154 | sparsity=0.5215 | tv=0.0368
# [act=7 | test_sub=subject10 | ep=30] Loss=0.0504 | recon=0.1180 | bce=0.5921 | contrast=-2.5752 | sparsity=0.5253 | tv=0.0385
# [act=7 | test_sub=subject10 | ep=40] Loss=-0.0082 | recon=0.0998 | bce=0.5867 | contrast=-2.6887 | sparsity=0.5201 | tv=0.0395
# [act=7 | test_sub=subject10 | ep=50] Loss=-0.0365 | recon=0.0870 | bce=0.5863 | contrast=-2.7406 | sparsity=0.5193 | tv=0.0431
# [EVAL act=7 | test_sub=subject10] pseudo: BCE=0.6442, corr=0.3920, AUC(top/bot)=0.7664 | count(score=183.04, period=2.760s): pred=20.04, gt=20.00, MAE=0.04, MAPE=0.18%
# /tmp/ipython-input-1334207235.py:832: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data, labels=[f"steady\n(bottom {int(tb_frac*100)}%)", f"transition\n(top {int(tb_frac*100)}%)"])
# ================================================================================
# [BUILD] activity=8
#   trials: 10 subjects
# [act=8 | test_sub=subject1 | ep=1] Loss=1.1688 | recon=0.5704 | bce=0.6764 | contrast=-0.6182 | sparsity=0.5251 | tv=0.0123
# [act=8 | test_sub=subject1 | ep=10] Loss=0.3311 | recon=0.1353 | bce=0.6391 | contrast=-1.8435 | sparsity=0.5245 | tv=0.0240
# [act=8 | test_sub=subject1 | ep=20] Loss=0.2035 | recon=0.1073 | bce=0.6249 | contrast=-2.1323 | sparsity=0.5244 | tv=0.0309
# [act=8 | test_sub=subject1 | ep=30] Loss=0.1112 | recon=0.1035 | bce=0.6208 | contrast=-2.4149 | sparsity=0.5239 | tv=0.0327
# [act=8 | test_sub=subject1 | ep=40] Loss=0.1404 | recon=0.0994 | bce=0.6191 | contrast=-2.2945 | sparsity=0.5131 | tv=0.0383
# [act=8 | test_sub=subject1 | ep=50] Loss=0.0460 | recon=0.0782 | bce=0.6162 | contrast=-2.5310 | sparsity=0.5180 | tv=0.0363
# [EVAL act=8 | test_sub=subject1] pseudo: BCE=0.6596, corr=0.5074, AUC(top/bot)=0.8536 | count(score=41.07, period=3.480s): pred=19.42, gt=20.00, MAE=0.58, MAPE=2.90%
# [act=8 | test_sub=subject2 | ep=1] Loss=1.2217 | recon=0.6018 | bce=0.6762 | contrast=-0.5479 | sparsity=0.5286 | tv=0.0122
# [act=8 | test_sub=subject2 | ep=10] Loss=0.3583 | recon=0.1399 | bce=0.6408 | contrast=-1.7734 | sparsity=0.5256 | tv=0.0223
# [act=8 | test_sub=subject2 | ep=20] Loss=0.2726 | recon=0.1132 | bce=0.6272 | contrast=-1.9304 | sparsity=0.5262 | tv=0.0300
# [act=8 | test_sub=subject2 | ep=30] Loss=0.1794 | recon=0.0978 | bce=0.6190 | contrast=-2.1653 | sparsity=0.5285 | tv=0.0328
# [act=8 | test_sub=subject2 | ep=40] Loss=0.0904 | recon=0.0960 | bce=0.6224 | contrast=-2.4622 | sparsity=0.5193 | tv=0.0339
# [act=8 | test_sub=subject2 | ep=50] Loss=0.0952 | recon=0.0991 | bce=0.6166 | contrast=-2.4457 | sparsity=0.5322 | tv=0.0341
# [EVAL act=8 | test_sub=subject2] pseudo: BCE=0.6452, corr=0.8086, AUC(top/bot)=0.9918 | count(score=-7.16, period=3.460s): pred=19.83, gt=21.00, MAE=1.17, MAPE=5.59%
# [act=8 | test_sub=subject3 | ep=1] Loss=1.1842 | recon=0.5790 | bce=0.6801 | contrast=-0.6088 | sparsity=0.5265 | tv=0.0122
# [act=8 | test_sub=subject3 | ep=10] Loss=0.3515 | recon=0.1391 | bce=0.6420 | contrast=-1.7934 | sparsity=0.5210 | tv=0.0210
# [act=8 | test_sub=subject3 | ep=20] Loss=0.2243 | recon=0.1134 | bce=0.6286 | contrast=-2.0951 | sparsity=0.5255 | tv=0.0283
# [act=8 | test_sub=subject3 | ep=30] Loss=0.1487 | recon=0.1250 | bce=0.6237 | contrast=-2.3716 | sparsity=0.5259 | tv=0.0315
# [act=8 | test_sub=subject3 | ep=40] Loss=0.0305 | recon=0.0927 | bce=0.6169 | contrast=-2.6405 | sparsity=0.5282 | tv=0.0370
# [act=8 | test_sub=subject3 | ep=50] Loss=0.0396 | recon=0.0769 | bce=0.6152 | contrast=-2.5510 | sparsity=0.5288 | tv=0.0348
# [EVAL act=8 | test_sub=subject3] pseudo: BCE=0.6520, corr=0.7396, AUC(top/bot)=0.9808 | count(score=-7.84, period=3.180s): pred=19.97, gt=21.00, MAE=1.03, MAPE=4.91%
# [act=8 | test_sub=subject4 | ep=1] Loss=1.2038 | recon=0.6039 | bce=0.6767 | contrast=-0.6166 | sparsity=0.5265 | tv=0.0146
# [act=8 | test_sub=subject4 | ep=10] Loss=0.3486 | recon=0.1424 | bce=0.6429 | contrast=-1.8152 | sparsity=0.5158 | tv=0.0230
# [act=8 | test_sub=subject4 | ep=20] Loss=0.2238 | recon=0.1030 | bce=0.6259 | contrast=-2.0512 | sparsity=0.5239 | tv=0.0276
# [act=8 | test_sub=subject4 | ep=30] Loss=0.1102 | recon=0.0867 | bce=0.6203 | contrast=-2.3605 | sparsity=0.5263 | tv=0.0307
# [act=8 | test_sub=subject4 | ep=40] Loss=0.0727 | recon=0.1011 | bce=0.6240 | contrast=-2.5455 | sparsity=0.5267 | tv=0.0298
# [act=8 | test_sub=subject4 | ep=50] Loss=0.0175 | recon=0.0824 | bce=0.6133 | contrast=-2.6360 | sparsity=0.5264 | tv=0.0362
# [EVAL act=8 | test_sub=subject4] pseudo: BCE=0.6303, corr=0.6853, AUC(top/bot)=0.9722 | count(score=-20.54, period=3.340s): pred=18.70, gt=19.00, MAE=0.30, MAPE=1.58%
# [act=8 | test_sub=subject5 | ep=1] Loss=1.2001 | recon=0.5963 | bce=0.6813 | contrast=-0.6109 | sparsity=0.5152 | tv=0.0142
# [act=8 | test_sub=subject5 | ep=10] Loss=0.3587 | recon=0.1423 | bce=0.6394 | contrast=-1.7691 | sparsity=0.5161 | tv=0.0231
# [act=8 | test_sub=subject5 | ep=20] Loss=0.2369 | recon=0.1129 | bce=0.6266 | contrast=-2.0429 | sparsity=0.5220 | tv=0.0292
# [act=8 | test_sub=subject5 | ep=30] Loss=0.2046 | recon=0.1079 | bce=0.6277 | contrast=-2.1382 | sparsity=0.5217 | tv=0.0308
# [act=8 | test_sub=subject5 | ep=40] Loss=0.1270 | recon=0.0918 | bce=0.6197 | contrast=-2.3258 | sparsity=0.5339 | tv=0.0322
# [act=8 | test_sub=subject5 | ep=50] Loss=0.0202 | recon=0.0805 | bce=0.6108 | contrast=-2.6134 | sparsity=0.5271 | tv=0.0377
# [EVAL act=8 | test_sub=subject5] pseudo: BCE=0.6384, corr=0.8170, AUC(top/bot)=0.9864 | count(score=284.33, period=2.800s): pred=19.39, gt=20.00, MAE=0.61, MAPE=3.07%
# [act=8 | test_sub=subject6 | ep=1] Loss=1.2128 | recon=0.6040 | bce=0.6817 | contrast=-0.5897 | sparsity=0.5087 | tv=0.0109
# [act=8 | test_sub=subject6 | ep=10] Loss=0.3562 | recon=0.1333 | bce=0.6497 | contrast=-1.7801 | sparsity=0.5168 | tv=0.0191
# [act=8 | test_sub=subject6 | ep=20] Loss=0.2681 | recon=0.1008 | bce=0.6372 | contrast=-1.9353 | sparsity=0.5275 | tv=0.0258
# [act=8 | test_sub=subject6 | ep=30] Loss=0.1307 | recon=0.1004 | bce=0.6260 | contrast=-2.3563 | sparsity=0.5263 | tv=0.0302
# [act=8 | test_sub=subject6 | ep=40] Loss=0.0912 | recon=0.0900 | bce=0.6228 | contrast=-2.4445 | sparsity=0.5271 | tv=0.0316
# [act=8 | test_sub=subject6 | ep=50] Loss=0.0093 | recon=0.0832 | bce=0.6209 | contrast=-2.6866 | sparsity=0.5219 | tv=0.0337
# [EVAL act=8 | test_sub=subject6] pseudo: BCE=0.6175, corr=0.7244, AUC(top/bot)=0.9815 | count(score=-400.02, period=2.420s): pred=19.04, gt=20.00, MAE=0.96, MAPE=4.79%
# [act=8 | test_sub=subject7 | ep=1] Loss=1.2061 | recon=0.6102 | bce=0.6795 | contrast=-0.6447 | sparsity=0.5375 | tv=0.0114
# [act=8 | test_sub=subject7 | ep=10] Loss=0.3290 | recon=0.1412 | bce=0.6447 | contrast=-1.8804 | sparsity=0.5151 | tv=0.0212
# [act=8 | test_sub=subject7 | ep=20] Loss=0.1864 | recon=0.1094 | bce=0.6292 | contrast=-2.2086 | sparsity=0.5233 | tv=0.0286
# [act=8 | test_sub=subject7 | ep=30] Loss=0.0788 | recon=0.1016 | bce=0.6254 | contrast=-2.5258 | sparsity=0.5163 | tv=0.0313
# [act=8 | test_sub=subject7 | ep=40] Loss=0.0260 | recon=0.0902 | bce=0.6168 | contrast=-2.6448 | sparsity=0.5275 | tv=0.0345
# [act=8 | test_sub=subject7 | ep=50] Loss=-0.0225 | recon=0.0743 | bce=0.6076 | contrast=-2.7273 | sparsity=0.5320 | tv=0.0374
# [EVAL act=8 | test_sub=subject7] pseudo: BCE=0.6473, corr=0.6738, AUC(top/bot)=0.9442 | count(score=15.34, period=2.780s): pred=20.26, gt=21.00, MAE=0.74, MAPE=3.53%
# [act=8 | test_sub=subject8 | ep=1] Loss=1.1924 | recon=0.5904 | bce=0.6764 | contrast=-0.6041 | sparsity=0.5217 | tv=0.0125
# [act=8 | test_sub=subject8 | ep=10] Loss=0.3019 | recon=0.1347 | bce=0.6403 | contrast=-1.9341 | sparsity=0.5143 | tv=0.0212
# [act=8 | test_sub=subject8 | ep=20] Loss=0.1820 | recon=0.1080 | bce=0.6256 | contrast=-2.2094 | sparsity=0.5272 | tv=0.0288
# [act=8 | test_sub=subject8 | ep=30] Loss=0.1030 | recon=0.1164 | bce=0.6327 | contrast=-2.5167 | sparsity=0.5132 | tv=0.0310
# [act=8 | test_sub=subject8 | ep=40] Loss=0.0152 | recon=0.0857 | bce=0.6168 | contrast=-2.6654 | sparsity=0.5285 | tv=0.0335
# [act=8 | test_sub=subject8 | ep=50] Loss=-0.0214 | recon=0.0770 | bce=0.6113 | contrast=-2.7395 | sparsity=0.5249 | tv=0.0363
# [EVAL act=8 | test_sub=subject8] pseudo: BCE=0.6730, corr=0.2466, AUC(top/bot)=0.6600 | count(score=751.60, period=2.400s): pred=21.33, gt=21.00, MAE=0.33, MAPE=1.59%
# [act=8 | test_sub=subject9 | ep=1] Loss=1.1799 | recon=0.6144 | bce=0.6761 | contrast=-0.7308 | sparsity=0.5300 | tv=0.0130
# [act=8 | test_sub=subject9 | ep=10] Loss=0.3276 | recon=0.1397 | bce=0.6420 | contrast=-1.8765 | sparsity=0.5207 | tv=0.0232
# [act=8 | test_sub=subject9 | ep=20] Loss=0.2114 | recon=0.1068 | bce=0.6286 | contrast=-2.1172 | sparsity=0.5242 | tv=0.0313
# [act=8 | test_sub=subject9 | ep=30] Loss=0.1208 | recon=0.1229 | bce=0.6315 | contrast=-2.4842 | sparsity=0.5304 | tv=0.0281
# [act=8 | test_sub=subject9 | ep=40] Loss=0.0248 | recon=0.0860 | bce=0.6144 | contrast=-2.6291 | sparsity=0.5290 | tv=0.0371
# [act=8 | test_sub=subject9 | ep=50] Loss=0.0615 | recon=0.0790 | bce=0.6136 | contrast=-2.4800 | sparsity=0.5264 | tv=0.0378
# [EVAL act=8 | test_sub=subject9] pseudo: BCE=0.6636, corr=0.4030, AUC(top/bot)=0.7599 | count(score=-487.96, period=2.880s): pred=20.62, gt=21.00, MAE=0.38, MAPE=1.82%
# [act=8 | test_sub=subject10 | ep=1] Loss=1.1734 | recon=0.6003 | bce=0.6716 | contrast=-0.6888 | sparsity=0.5250 | tv=0.0159
# [act=8 | test_sub=subject10 | ep=10] Loss=0.3305 | recon=0.1371 | bce=0.6367 | contrast=-1.8386 | sparsity=0.5182 | tv=0.0227
# [act=8 | test_sub=subject10 | ep=20] Loss=0.2005 | recon=0.1028 | bce=0.6218 | contrast=-2.1164 | sparsity=0.5256 | tv=0.0283
# [act=8 | test_sub=subject10 | ep=30] Loss=0.1056 | recon=0.1006 | bce=0.6197 | contrast=-2.4208 | sparsity=0.5263 | tv=0.0313
# [act=8 | test_sub=subject10 | ep=40] Loss=0.0431 | recon=0.0972 | bce=0.6185 | contrast=-2.6115 | sparsity=0.5221 | tv=0.0322
# [act=8 | test_sub=subject10 | ep=50] Loss=-0.0040 | recon=0.0813 | bce=0.6089 | contrast=-2.6884 | sparsity=0.5255 | tv=0.0364
# [EVAL act=8 | test_sub=subject10] pseudo: BCE=0.6556, corr=0.6107, AUC(top/bot)=0.9277 | count(score=47.68, period=2.880s): pred=19.91, gt=21.00, MAE=1.09, MAPE=5.19%
# /tmp/ipython-input-1334207235.py:832: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data, labels=[f"steady\n(bottom {int(tb_frac*100)}%)", f"transition\n(top {int(tb_frac*100)}%)"])
# ================================================================================
# [BUILD] activity=12
#   trials: 10 subjects
# [act=12 | test_sub=subject1 | ep=1] Loss=1.5751 | recon=1.0093 | bce=0.6810 | contrast=-0.7559 | sparsity=0.5351 | tv=0.0228
# [act=12 | test_sub=subject1 | ep=10] Loss=0.7247 | recon=0.2439 | bce=0.6165 | contrast=-0.8576 | sparsity=0.5450 | tv=0.0628
# [act=12 | test_sub=subject1 | ep=20] Loss=0.5969 | recon=0.1442 | bce=0.5984 | contrast=-0.8955 | sparsity=0.5436 | tv=0.0714
# [act=12 | test_sub=subject1 | ep=30] Loss=0.5259 | recon=0.1030 | bce=0.5809 | contrast=-0.9472 | sparsity=0.5491 | tv=0.0815
# [act=12 | test_sub=subject1 | ep=40] Loss=0.4115 | recon=0.0998 | bce=0.5722 | contrast=-1.2973 | sparsity=0.5565 | tv=0.0871
# [act=12 | test_sub=subject1 | ep=50] Loss=0.2600 | recon=0.1070 | bce=0.5658 | contrast=-1.8157 | sparsity=0.5661 | tv=0.0931
# [EVAL act=12 | test_sub=subject1] pseudo: BCE=0.6455, corr=0.2958, AUC(top/bot)=0.7656 | count(score=40.85, period=1.080s): pred=19.91, gt=40.00, MAE=20.09, MAPE=50.23%
# [act=12 | test_sub=subject2 | ep=1] Loss=1.5498 | recon=0.9814 | bce=0.6888 | contrast=-0.7577 | sparsity=0.5185 | tv=0.0159
# [act=12 | test_sub=subject2 | ep=10] Loss=0.7077 | recon=0.2298 | bce=0.6129 | contrast=-0.8555 | sparsity=0.5479 | tv=0.0601
# [act=12 | test_sub=subject2 | ep=20] Loss=0.5850 | recon=0.1332 | bce=0.5937 | contrast=-0.8847 | sparsity=0.5482 | tv=0.0693
# [act=12 | test_sub=subject2 | ep=30] Loss=0.5228 | recon=0.0972 | bce=0.5763 | contrast=-0.9252 | sparsity=0.5527 | tv=0.0817
# [act=12 | test_sub=subject2 | ep=40] Loss=0.4550 | recon=0.0877 | bce=0.5677 | contrast=-1.0938 | sparsity=0.5482 | tv=0.0900
# [act=12 | test_sub=subject2 | ep=50] Loss=0.3007 | recon=0.1021 | bce=0.5665 | contrast=-1.6563 | sparsity=0.5532 | tv=0.0915
# [EVAL act=12 | test_sub=subject2] pseudo: BCE=0.6480, corr=0.3579, AUC(top/bot)=0.8571 | count(score=110.76, period=0.940s): pred=21.79, gt=44.00, MAE=22.21, MAPE=50.48%
# [act=12 | test_sub=subject3 | ep=1] Loss=1.5811 | recon=1.0154 | bce=0.6859 | contrast=-0.7548 | sparsity=0.5095 | tv=0.0217
# [act=12 | test_sub=subject3 | ep=10] Loss=0.7200 | recon=0.2445 | bce=0.6102 | contrast=-0.8570 | sparsity=0.5494 | tv=0.0627
# [act=12 | test_sub=subject3 | ep=20] Loss=0.5856 | recon=0.1419 | bce=0.5912 | contrast=-0.9088 | sparsity=0.5546 | tv=0.0713
# [act=12 | test_sub=subject3 | ep=30] Loss=0.4818 | recon=0.1110 | bce=0.5784 | contrast=-1.1162 | sparsity=0.5571 | tv=0.0791
# [act=12 | test_sub=subject3 | ep=40] Loss=0.2957 | recon=0.1175 | bce=0.5710 | contrast=-1.7388 | sparsity=0.5593 | tv=0.0850
# [act=12 | test_sub=subject3 | ep=50] Loss=0.1903 | recon=0.1047 | bce=0.5605 | contrast=-2.0188 | sparsity=0.5632 | tv=0.0907
# [EVAL act=12 | test_sub=subject3] pseudo: BCE=0.6502, corr=0.2848, AUC(top/bot)=0.6122 | count(score=118.87, period=1.000s): pred=20.48, gt=42.00, MAE=21.52, MAPE=51.24%
# [act=12 | test_sub=subject4 | ep=1] Loss=1.5694 | recon=1.0025 | bce=0.6876 | contrast=-0.7556 | sparsity=0.5096 | tv=0.0201
# [act=12 | test_sub=subject4 | ep=10] Loss=0.7197 | recon=0.2430 | bce=0.6137 | contrast=-0.8622 | sparsity=0.5476 | tv=0.0604
# [act=12 | test_sub=subject4 | ep=20] Loss=0.5822 | recon=0.1441 | bce=0.5928 | contrast=-0.9326 | sparsity=0.5555 | tv=0.0700
# [act=12 | test_sub=subject4 | ep=30] Loss=0.4573 | recon=0.1214 | bce=0.5802 | contrast=-1.2383 | sparsity=0.5558 | tv=0.0803
# [act=12 | test_sub=subject4 | ep=40] Loss=0.2751 | recon=0.1220 | bce=0.5751 | contrast=-1.8295 | sparsity=0.5510 | tv=0.0837
# [act=12 | test_sub=subject4 | ep=50] Loss=0.1604 | recon=0.1084 | bce=0.5683 | contrast=-2.1435 | sparsity=0.5481 | tv=0.0856
# [EVAL act=12 | test_sub=subject4] pseudo: BCE=0.6544, corr=0.0181, AUC(top/bot)=0.4490 | count(score=970.77, period=1.000s): pred=20.48, gt=42.00, MAE=21.52, MAPE=51.24%
# [act=12 | test_sub=subject5 | ep=1] Loss=1.5607 | recon=0.9956 | bce=0.6847 | contrast=-0.7621 | sparsity=0.5227 | tv=0.0229
# [act=12 | test_sub=subject5 | ep=10] Loss=0.7245 | recon=0.2446 | bce=0.6158 | contrast=-0.8559 | sparsity=0.5436 | tv=0.0609
# [act=12 | test_sub=subject5 | ep=20] Loss=0.5984 | recon=0.1469 | bce=0.5973 | contrast=-0.8979 | sparsity=0.5468 | tv=0.0708
# [act=12 | test_sub=subject5 | ep=30] Loss=0.5282 | recon=0.1093 | bce=0.5813 | contrast=-0.9675 | sparsity=0.5559 | tv=0.0834
# [act=12 | test_sub=subject5 | ep=40] Loss=0.4152 | recon=0.1054 | bce=0.5721 | contrast=-1.3039 | sparsity=0.5532 | tv=0.0912
# [act=12 | test_sub=subject5 | ep=50] Loss=0.2569 | recon=0.1054 | bce=0.5677 | contrast=-1.8139 | sparsity=0.5484 | tv=0.0918
# [EVAL act=12 | test_sub=subject5] pseudo: BCE=0.6370, corr=0.1799, AUC(top/bot)=0.6531 | count(score=-39.91, period=1.040s): pred=19.69, gt=40.00, MAE=20.31, MAPE=50.77%
# [act=12 | test_sub=subject6 | ep=1] Loss=1.5775 | recon=1.0084 | bce=0.6800 | contrast=-0.7522 | sparsity=0.5463 | tv=0.0270
# [act=12 | test_sub=subject6 | ep=10] Loss=0.7259 | recon=0.2422 | bce=0.6165 | contrast=-0.8482 | sparsity=0.5507 | tv=0.0579
# [act=12 | test_sub=subject6 | ep=20] Loss=0.5875 | recon=0.1423 | bce=0.5965 | contrast=-0.9196 | sparsity=0.5547 | tv=0.0682
# [act=12 | test_sub=subject6 | ep=30] Loss=0.4602 | recon=0.1176 | bce=0.5846 | contrast=-1.2279 | sparsity=0.5542 | tv=0.0780
# [act=12 | test_sub=subject6 | ep=40] Loss=0.3333 | recon=0.1176 | bce=0.5796 | contrast=-1.6329 | sparsity=0.5476 | tv=0.0821
# [act=12 | test_sub=subject6 | ep=50] Loss=0.1975 | recon=0.1049 | bce=0.5687 | contrast=-2.0201 | sparsity=0.5628 | tv=0.0865
# [EVAL act=12 | test_sub=subject6] pseudo: BCE=0.6217, corr=0.6544, AUC(top/bot)=0.8571 | count(score=30.56, period=1.000s): pred=20.48, gt=42.00, MAE=21.52, MAPE=51.24%
# [act=12 | test_sub=subject7 | ep=1] Loss=1.5619 | recon=0.9991 | bce=0.6790 | contrast=-0.7589 | sparsity=0.5327 | tv=0.0248
# [act=12 | test_sub=subject7 | ep=10] Loss=0.7190 | recon=0.2460 | bce=0.6079 | contrast=-0.8628 | sparsity=0.5535 | tv=0.0660
# [act=12 | test_sub=subject7 | ep=20] Loss=0.5807 | recon=0.1469 | bce=0.5911 | contrast=-0.9395 | sparsity=0.5509 | tv=0.0721
# [act=12 | test_sub=subject7 | ep=30] Loss=0.4484 | recon=0.1218 | bce=0.5796 | contrast=-1.2658 | sparsity=0.5532 | tv=0.0806
# [act=12 | test_sub=subject7 | ep=40] Loss=0.2763 | recon=0.1201 | bce=0.5749 | contrast=-1.8211 | sparsity=0.5533 | tv=0.0850
# [act=12 | test_sub=subject7 | ep=50] Loss=0.1740 | recon=0.1051 | bce=0.5654 | contrast=-2.0868 | sparsity=0.5601 | tv=0.0875
# [EVAL act=12 | test_sub=subject7] pseudo: BCE=0.6624, corr=0.1524, AUC(top/bot)=0.6327 | count(score=48.35, period=1.120s): pred=18.29, gt=38.00, MAE=19.71, MAPE=51.88%
# [act=12 | test_sub=subject8 | ep=1] Loss=1.5919 | recon=1.0244 | bce=0.6904 | contrast=-0.7643 | sparsity=0.5105 | tv=0.0216
# [act=12 | test_sub=subject8 | ep=10] Loss=0.7413 | recon=0.2541 | bce=0.6208 | contrast=-0.8472 | sparsity=0.5477 | tv=0.0557
# [act=12 | test_sub=subject8 | ep=20] Loss=0.6042 | recon=0.1489 | bce=0.6014 | contrast=-0.8996 | sparsity=0.5530 | tv=0.0658
# [act=12 | test_sub=subject8 | ep=30] Loss=0.5219 | recon=0.1123 | bce=0.5867 | contrast=-1.0090 | sparsity=0.5531 | tv=0.0748
# [act=12 | test_sub=subject8 | ep=40] Loss=0.3759 | recon=0.1114 | bce=0.5795 | contrast=-1.4762 | sparsity=0.5578 | tv=0.0816
# [act=12 | test_sub=subject8 | ep=50] Loss=0.2546 | recon=0.1098 | bce=0.5708 | contrast=-1.8465 | sparsity=0.5540 | tv=0.0855
# [EVAL act=12 | test_sub=subject8] pseudo: BCE=0.6567, corr=0.5298, AUC(top/bot)=0.9184 | count(score=-87.33, period=2.040s): pred=10.04, gt=40.00, MAE=29.96, MAPE=74.90%
# [act=12 | test_sub=subject9 | ep=1] Loss=1.5570 | recon=0.9912 | bce=0.6762 | contrast=-0.7444 | sparsity=0.5465 | tv=0.0182
# [act=12 | test_sub=subject9 | ep=10] Loss=0.7211 | recon=0.2451 | bce=0.6148 | contrast=-0.8701 | sparsity=0.5502 | tv=0.0607
# [act=12 | test_sub=subject9 | ep=20] Loss=0.5544 | recon=0.1465 | bce=0.5957 | contrast=-1.0398 | sparsity=0.5518 | tv=0.0690
# [act=12 | test_sub=subject9 | ep=30] Loss=0.4199 | recon=0.1237 | bce=0.5837 | contrast=-1.3791 | sparsity=0.5545 | tv=0.0765
# [act=12 | test_sub=subject9 | ep=40] Loss=0.2521 | recon=0.1197 | bce=0.5745 | contrast=-1.8956 | sparsity=0.5526 | tv=0.0802
# [act=12 | test_sub=subject9 | ep=50] Loss=0.1361 | recon=0.1075 | bce=0.5711 | contrast=-2.2309 | sparsity=0.5501 | tv=0.0837
# [EVAL act=12 | test_sub=subject9] pseudo: BCE=0.6531, corr=0.0803, AUC(top/bot)=0.4844 | count(score=-1180.11, period=1.040s): pred=20.67, gt=40.00, MAE=19.33, MAPE=48.32%
# [act=12 | test_sub=subject10 | ep=1] Loss=1.5695 | recon=1.0044 | bce=0.6870 | contrast=-0.7561 | sparsity=0.5018 | tv=0.0230
# [act=12 | test_sub=subject10 | ep=10] Loss=0.7212 | recon=0.2423 | bce=0.6157 | contrast=-0.8586 | sparsity=0.5483 | tv=0.0558
# [act=12 | test_sub=subject10 | ep=20] Loss=0.5751 | recon=0.1455 | bce=0.5949 | contrast=-0.9673 | sparsity=0.5560 | tv=0.0690
# [act=12 | test_sub=subject10 | ep=30] Loss=0.3930 | recon=0.1236 | bce=0.5823 | contrast=-1.4662 | sparsity=0.5563 | tv=0.0783
# [act=12 | test_sub=subject10 | ep=40] Loss=0.2428 | recon=0.1181 | bce=0.5773 | contrast=-1.9279 | sparsity=0.5480 | tv=0.0808
# [act=12 | test_sub=subject10 | ep=50] Loss=0.1871 | recon=0.1004 | bce=0.5669 | contrast=-2.0284 | sparsity=0.5568 | tv=0.0849
# [EVAL act=12 | test_sub=subject10] pseudo: BCE=0.6024, corr=0.5591, AUC(top/bot)=1.0000 | count(score=-10.25, period=0.520s): pred=39.38, gt=40.00, MAE=0.62, MAPE=1.54%
# /tmp/ipython-input-1334207235.py:832: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data, labels=[f"steady\n(bottom {int(tb_frac*100)}%)", f"transition\n(top {int(tb_frac*100)}%)"])
# ================================================================================
# [SUMMARY] per-activity (LOSO mean)
#   act=6 | MAE=0.66 | MAPE=3.29% | pseudo(BCE=0.6230, corr=0.7175, AUC=0.9412)
#   act=7 | MAE=2.41 | MAPE=12.63% | pseudo(BCE=0.6296, corr=0.6330, AUC=0.9137)
#   act=8 | MAE=0.72 | MAPE=3.50% | pseudo(BCE=0.6483, corr=0.6216, AUC=0.9058)
#   act=12 | MAE=19.68 | MAPE=48.18% | pseudo(BCE=0.6431, corr=0.3113, AUC=0.7230)
#
# [OVERALL] MAE=5.87 | MAPE=16.90% over 40 folds
